# %%
# !pip install wbdata
# Out:
# Collecting wbdata
#   Using cached wbdata-1.1.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting appdirs<2,>=1.4 (from wbdata)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: backoff<3,>=2.2.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.2.1)
# Collecting cachetools<6,>=5.3.2 (from wbdata)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting dateparser<2,>=1.2.0 (from wbdata)
#   Using cached dateparser-1.3.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: decorator<6,>=5.1.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (5.1.1)
# Requirement already satisfied: requests<3,>=2.0 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.32.3)
# Collecting shelved-cache<0.4,>=0.3.1 (from wbdata)
#   Using cached shelved_cache-0.3.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting tabulate<1,>=0.8.5 (from wbdata)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2025.10.23)
# Collecting tzlocal>=0.2 (from dateparser<2,>=1.2.0->wbdata)
#   Using cached tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.7.0->dateparser<2,>=1.2.0->wbdata) (1.17.0)
# Using cached wbdata-1.1.0-py3-none-any.whl (18 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached dateparser-1.3.0-py3-none-any.whl (318 kB)
# Using cached shelved_cache-0.3.1-py3-none-any.whl (7.8 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Installing collected packages: appdirs, tzlocal, tabulate, cachetools, shelved-cache, dateparser, wbdata
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 6.2.1
#     Uninstalling cachetools-6.2.1:
#       Successfully uninstalled cachetools-6.2.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [wbdata]2m5/7 [dateparser]
# Successfully installed appdirs-1.4.4 cachetools-5.5.2 dateparser-1.3.0 shelved-cache-0.3.1 tabulate-0.9.0 tzlocal-5.3.1 wbdata-1.1.0

# %%
import wbdata
import pandas as pd
import matplotlib.pyplot as plt

# Indicator: Water stress (% of available freshwater)
indicator = {"ER.H2O.FWST.ZS": "Water Stress (%)"}

# Get data for Canada from 1990–2023
df = wbdata.get_dataframe(
    indicator,
    country="BA",
    date=(pd.Timestamp("1990-01-01"), pd.Timestamp("2023-01-01"))
)

# Reset index (removes MultiIndex)
df = df.reset_index()

# Convert date column to datetime
df["date"] = pd.to_datetime(df["date"])

# Extract year
df["year"] = df["date"].dt.year

# Sort chronologically
df = df.sort_values("year")

# Plot
plt.figure(figsize=(10, 6))
plt.plot(df["year"], df["Water Stress (%)"], marker="o")

plt.title("Water Stress Over Time in Brazil")
plt.xlabel("Year")
plt.ylabel("Freshwater withdrawal (% of available)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Key '-7434702560165559802' not in persistent cache.
# Key '6645290533509248137' not in persistent cache.
# Key '-8536621438201745173' not in persistent cache.
# Key '-1327260667700091078' not in persistent cache.
# Key '-5017551923653860904' not in persistent cache.
# Key '4813976258934523201' not in persistent cache.
# Key '3613365519401858730' not in persistent cache.
# Key '-6934294245907501402' not in persistent cache.
# Key '86405745314886174' not in persistent cache.
# Key '2765684053914999322' not in persistent cache.
# Key '2754744319689806748' not in persistent cache.
# Key '8248480812134579311' not in persistent cache.
# Key '-7648659191038710075' not in persistent cache.
# Key '6653964912235799376' not in persistent cache.
# Key '-3439866138592288417' not in persistent cache.
# Key '5027719822596633947' not in persistent cache.
# Key '5191051304463431217' not in persistent cache.
# Key '5248162200976814355' not in persistent cache.
# Key '8710120819011315486' not in persistent cache.
# Key '-7057344946098122982' not in persistent cache.
# Key '-6440184749750053373' not in persistent cache.
# Key '-3629181362232767406' not in persistent cache.
# Key '-2921115235202169104' not in persistent cache.
# Key '6910412947386215001' not in persistent cache.
# Key '5709802207853550530' not in persistent cache.
# Key '-4837857557455809602' not in persistent cache.
# Key '2182842433766577974' not in persistent cache.
# Key '4862120742366691122' not in persistent cache.
# Key '2773484024001866134' not in persistent cache.
# Key '-3177166155172586256' not in persistent cache.
# Key '6418467203998532799' not in persistent cache.
# Key '2274347233563490634' not in persistent cache.
# Key '-7819483817264597159' not in persistent cache.
# Key '-1999569761726163492' not in persistent cache.
# Key '811433625791122475' not in persistent cache.
# Key '-6177484766330351212' not in persistent cache.
# Key '-2715526148295850081' not in persistent cache.
# Key '-36247839695736933' not in persistent cache.
# Key '7626941645287189501' not in persistent cache.
# Key '7790273127153986771' not in persistent cache.
# Key '4099981871200216945' not in persistent cache.
# Key '-4515234019920950566' not in persistent cache.
# Key '-5715844759453615037' not in persistent cache.
# Key '-9217475236128118344' not in persistent cache.
# Key '-2196775244905730768' not in persistent cache.
# Key '-6563526224940474445' not in persistent cache.
# Key '5064839776398242452' not in persistent cache.
# Key '3512546980208158190' not in persistent cache.
# Key '-5338563734330274371' not in persistent cache.
# Key '8964060368944235080' not in persistent cache.
# Key '-1129770681883852713' not in persistent cache.
# Key '291785990670212826' not in persistent cache.
# Key '7501146761171866921' not in persistent cache.
# Key '-3886129013933974894' not in persistent cache.
# Key '3974186987084894365' not in persistent cache.
# Key '6653465295685007513' not in persistent cache.
# Key '-4130089293041617669' not in persistent cache.
# Key '-8365115194159188527' not in persistent cache.
# Key '6391337623596593263' not in persistent cache.
# Key '9220508404094650705' not in persistent cache.
# Key '-3424489007057238719' not in persistent cache.
# Key '-2527762100747373898' not in persistent cache.
# Key '94580507490645550' not in persistent cache.
# Key '-4272170472544098127' not in persistent cache.
# Key '-2612612826804342100' not in persistent cache.
# Key '-1517233717343937665' not in persistent cache.
# Key '1032370353192324565' not in persistent cache.
# Key '-3111749617242717600' not in persistent cache.
# Key '-1761193996451580440' not in persistent cache.
# Key '-339637323897514901' not in persistent cache.
# Key '-176305842030717631' not in persistent cache.
# Key '-4517552328501702621' not in persistent cache.
# Key '-1055593710467201490' not in persistent cache.
# Key '6022041981117279786' not in persistent cache.
# Key '2240844794480981267' not in persistent cache.
# Key '-8996538508726916254' not in persistent cache.
# Key '5759914309028865536' not in persistent cache.
# Key '-2855301582092301975' not in persistent cache.
# Key '-4055912321624966446' not in persistent cache.
# Key '3843171986775225038' not in persistent cache.
# Key '-7582872095711939002' not in persistent cache.
# Key '-4903593787111825854' not in persistent cache.
# Key '-4956853802757824599' not in persistent cache.
# Key '536882689686947964' not in persistent cache.
# Key '-1311870622761157934' not in persistent cache.
# Key '-1057633210211831971' not in persistent cache.
# Key '-4105434972405062939' not in persistent cache.
# Key '-2683878299850997400' not in persistent cache.
# Key '4525482470650656695' not in persistent cache.
# Key '-6861793304455185120' not in persistent cache.
# Key '998522696563684139' not in persistent cache.
# Key '3677801005163797287' not in persistent cache.
# Key '-103396181472501232' not in persistent cache.
# Key '7105964589029152863' not in persistent cache.
# Key '3415673333075383037' not in persistent cache.
# Key '-801185175061416346' not in persistent cache.
# Key '-6400153297578448945' not in persistent cache.
# Key '5897288393806110667' not in persistent cache.
# Key '-2881083783030564676' not in persistent cache.
# Key '-7247834763065308353' not in persistent cache.
# Key '5924721488902921995' not in persistent cache.
# Key '6789723035309346861' not in persistent cache.
# Key '-7042528749635730749' not in persistent cache.
# Key '1921459136830583655' not in persistent cache.
# Key '-4029191042343868735' not in persistent cache.
# Key '5566442316827250320' not in persistent cache.
# Key '5820679729376576283' not in persistent cache.
# Key '-4273151321451511510' not in persistent cache.
# Key '-2851594648897445971' not in persistent cache.
# Key '4357766121604208124' not in persistent cache.
# Key '-7029509653501633691' not in persistent cache.
# Key '7876835636152092393' not in persistent cache.
# Key '3510084656117348716' not in persistent cache.
# Key '6774916758115907022' not in persistent cache.
# Key '-4462466545091990499' not in persistent cache.
# Key '-8152757801045760325' not in persistent cache.
# Key '1678770381542623780' not in persistent cache.
# Key '-6567869646624897516' not in persistent cache.
# Key '8377243950410150793' not in persistent cache.
# Key '-3048800132077013247' not in persistent cache.
# Key '-369521823476900099' not in persistent cache.
# Key '-8779134954414322050' not in persistent cache.
# Key '3716958940120777176' not in persistent cache.
# Key '-5134151774417655385' not in persistent cache.
# Key '2122443040221997241' not in persistent cache.
# Key '-925358721971233727' not in persistent cache.
# Key '4894555333567199940' not in persistent cache.
# Key '7705558721084485907' not in persistent cache.
# Key '716640328963012220' not in persistent cache.
# Key '4178598946997513351' not in persistent cache.
# Key '6857877255597626499' not in persistent cache.
# Key '-3925677333128998683' not in persistent cache.
# Key '-3762345851262201413' not in persistent cache.
# Key '-7452637107215971239' not in persistent cache.
# Key '2378891075372412866' not in persistent cache.
# Key '1178280335839748395' not in persistent cache.
# Key '-2323350140834754912' not in persistent cache.
# Key '4697349850387632664' not in persistent cache.
# Key '330598870352888987' not in persistent cache.
# Key '640521213732119114' not in persistent cache.
# Key '1735900323192523549' not in persistent cache.
# Key '-7115210391345909012' not in persistent cache.
# Key '141384423293743614' not in persistent cache.
# Key '-2906417338899487354' not in persistent cache.
# Key '2913496716638946313' not in persistent cache.
# Key '5724500104156232280' not in persistent cache.
# Key '-1264418287965241407' not in persistent cache.
# Key '2197540330069259724' not in persistent cache.
# Key '4876818638669372872' not in persistent cache.
# Key '-5906735950057252310' not in persistent cache.
# Key '8304982222534728448' not in persistent cache.
# Key '9013048349565326750' not in persistent cache.
# Key '397832458444159239' not in persistent cache.
# Key '-802778281088505232' not in persistent cache.
# Key '-4304408757763008539' not in persistent cache.
# Key '2716291233459379037' not in persistent cache.
# Key '-1650459746575364640' not in persistent cache.
# Key '-4476136935881903158' not in persistent cache.
# Key '8019956958653196068' not in persistent cache.
# Key '-831153755885236493' not in persistent cache.
# Key '6425441058754416133' not in persistent cache.
# Key '3377639296561185165' not in persistent cache.
# Key '9197553352099618832' not in persistent cache.
# Key '-6438187334092646817' not in persistent cache.
# Key '5019638347495431112' not in persistent cache.
# Key '8481596965529932243' not in persistent cache.
# Key '-7285868799579506225' not in persistent cache.
# Key '377320685403420209' not in persistent cache.
# Key '540652167270217479' not in persistent cache.
# Key '-3149639088683552347' not in persistent cache.
# Key '6681889093904831758' not in persistent cache.
# Key '5481278354372167287' not in persistent cache.
# Key '1979647877697663980' not in persistent cache.
# Key '9000347868920051556' not in persistent cache.
# Key '4633596888885307879' not in persistent cache.
# Key '3562221276918181393' not in persistent cache.
# Key '-453626561011584991' not in persistent cache.
# Key '628505929131695839' not in persistent cache.
# Key '-6998628685050358093' not in persistent cache.
# Key '4100954427201648439' not in persistent cache.
# Key '-3899135785463906573' not in persistent cache.
# Key '3488947330653353229' not in persistent cache.
# Key '941740205297044583' not in persistent cache.
# Key '9210625568587957436' not in persistent cache.
# Key '36607083396122798' not in persistent cache.
# Key '2329808120594026592' not in persistent cache.
# Key '-703686718414094508' not in persistent cache.
# Key '558854965763426227' not in persistent cache.
# Key '-5218166562252765497' not in persistent cache.
# Key '-5117854491310902056' not in persistent cache.
# Key '-4227648737339588751' not in persistent cache.
# Key '-6788523820286393185' not in persistent cache.
# Key '-3040330650489361349' not in persistent cache.
# Key '-4344707218558737097' not in persistent cache.
# Key '6722793306952012927' not in persistent cache.
# Key '5850914116554135241' not in persistent cache.
# Key '-2086318825800907720' not in persistent cache.
# Key '7279111703686325816' not in persistent cache.
# Key '1976286591880365645' not in persistent cache.
# Key '-1633887579552202755' not in persistent cache.
# Key '-8917123529292708200' not in persistent cache.
# Key '2586396969174642833' not in persistent cache.
# Key '3361560539668160070' not in persistent cache.
# Key '-4094280458380515079' not in persistent cache.
# Key '-8360690699507845016' not in persistent cache.
# Key '-4142676898672976180' not in persistent cache.
# Key '1830849134020340066' not in persistent cache.
# Key '-5540191314993833506' not in persistent cache.
# Key '-8520800227279413471' not in persistent cache.
# Key '6927697033841115294' not in persistent cache.
# Key '-6897788635379392262' not in persistent cache.
# Key '5926474046495458863' not in persistent cache.
# Key '5023601621965699930' not in persistent cache.
# Key '2542958373677888991' not in persistent cache.
# Key '6602956397480357741' not in persistent cache.
# Key '3949056055095270306' not in persistent cache.
# Key '5458656875189175387' not in persistent cache.
# Key '-3659813067163643971' not in persistent cache.
# Key '-9126220225257541352' not in persistent cache.
# Key '5605254501439504649' not in persistent cache.
# Key '8328747836542620829' not in persistent cache.
# Key '7259942299084639374' not in persistent cache.
# Key '3384947135028013488' not in persistent cache.
# Key '7245009418247721112' not in persistent cache.
# Key '2903043690657256047' not in persistent cache.
# Key '5044847310762349713' not in persistent cache.
# Key '3715161946993450812' not in persistent cache.
# Key '807349177155552338' not in persistent cache.
# Key '-2855289650604906325' not in persistent cache.
# Key '-3606500500146982196' not in persistent cache.
# Key '7743197793944690848' not in persistent cache.
# Key '6360176462905754967' not in persistent cache.
# Key '3217312717966342344' not in persistent cache.
# Key '3246492209608405305' not in persistent cache.
# Key '1759232349458987990' not in persistent cache.
# Key '-5836408730712978950' not in persistent cache.
# Key '3976178963039253406' not in persistent cache.
# Key '-3408450701665059984' not in persistent cache.
# Key '-6117658071177209404' not in persistent cache.
# Key '4119038637415840916' not in persistent cache.

# %%
import wbdata
import pandas as pd
import matplotlib.pyplot as plt

# Indicator: Water stress (% of available freshwater)
indicator = {"ER.H2O.FWST.ZS": "Water Stress (%)"}

# Get data for Canada from 1990–2023
df = wbdata.get_dataframe(
    indicator,
    country="CA",
    date=(pd.Timestamp("1990-01-01"), pd.Timestamp("2023-01-01"))
)

# Reset index (removes MultiIndex)
df = df.reset_index()

# Convert date column to datetime
df["date"] = pd.to_datetime(df["date"])

# Extract year
df["year"] = df["date"].dt.year

# Sort chronologically
df = df.sort_values("year")

# Plot
plt.figure(figsize=(10, 6))
plt.plot(df["year"], df["Water Stress (%)"], marker="o")

plt.title("Water Stress Over Time in Canada")
plt.xlabel("Year")
plt.ylabel("Freshwater withdrawal (% of available)")
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import wbdata
import pandas as pd
import matplotlib.pyplot as plt

# Indicator
indicator = {"ER.H2O.FWST.ZS": "Water Stress (%)"}

# Countries
countries = ["BH", "SA", "IN", "BR", "RU", "CA"]

# Date range
date_range = (pd.Timestamp("1990-01-01"), pd.Timestamp("2023-01-01"))

# Fetch data
df = wbdata.get_dataframe(indicator, country=countries, date=date_range)

# Clean
df = df.reset_index()
df["date"] = pd.to_datetime(df["date"])
df["year"] = df["date"].dt.year

# Pivot to wide format
wide = df.pivot_table(index="year",
                      columns="country",
                      values="Water Stress (%)").sort_index()

# Plot
plt.figure(figsize=(12, 7))

for country in wide.columns:
    plt.plot(wide.index, wide[country], marker='o', linewidth=2, label=country)

plt.title("Water Stress Over Time (1990–2023)")
plt.xlabel("Year")
plt.ylabel("Freshwater withdrawal (% of available)")
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(title="Country")
plt.tight_layout()
plt.show()

# %%
import wbdata
import pandas as pd
import matplotlib.pyplot as plt

# Indicator
indicator = {"ER.H2O.FWST.ZS": "Water Stress (%)"}

# Countries
countries = ["BH", "SA", "IN", "BR", "RU", "CA"]

# Date range
date_range = (pd.Timestamp("1990-01-01"), pd.Timestamp("2023-01-01"))

# Fetch data
df = wbdata.get_dataframe(indicator, country=countries, date=date_range)

# Clean
df = df.reset_index()
df["date"] = pd.to_datetime(df["date"])
df["year"] = df["date"].dt.year

# Pivot to wide format
wide = df.pivot_table(index="year",
                      columns="country",
                      values="Water Stress (%)").sort_index()

# ---- NORMALIZE ----
# Divide each column by its first available value and multiply by 100
wide_normalized = wide.div(wide.iloc[0]) * 100

# Plot normalized data
plt.figure(figsize=(12, 7))

for country in wide_normalized.columns:
    plt.plot(wide_normalized.index,
             wide_normalized[country],
             marker='o',
             linewidth=2,
             label=country)

plt.title("Water Stress (Normalized to 1990 = 100)")
plt.xlabel("Year")
plt.ylabel("Index (1990 = 100)")
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(title="Country")
plt.tight_layout()
plt.show()

# %%
import wbdata
import pandas as pd
import matplotlib.pyplot as plt

# Indicator
indicator = {"ER.H2O.FWST.ZS": "Water Stress (%)"}

# Countries
countries = ["BH", "SA", "IN", "BR", "RU", "CA"]

# Date range
date_range = (pd.Timestamp("1990-01-01"), pd.Timestamp("2023-01-01"))

# Fetch data
df = wbdata.get_dataframe(indicator, country=countries, date=date_range)

# Clean
df = df.reset_index()
df["date"] = pd.to_datetime(df["date"])
df["year"] = df["date"].dt.year

# Pivot to wide format
wide = (
    df.pivot_table(index="year", columns="country", values="Water Stress (%)")
      .sort_index()
)

# ---- FIND FIRST YEAR WITH FULL DATA ----
full_years = wide.dropna().index
if len(full_years) == 0:
    raise ValueError("No year has complete data for all countries in this range.")

base_year = int(full_years[0])
print(f"Base year with full data: {base_year}")

# ---- NORMALIZE TO BASE YEAR = 100 ----
wide_normalized = wide.div(wide.loc[base_year]) * 100

# Plot normalized data
plt.figure(figsize=(12, 7))

for country in wide_normalized.columns:
    plt.plot(
        wide_normalized.index,
        wide_normalized[country],
        marker="o",
        linewidth=2,
        label=country
    )

plt.title(f"Water Stress (Normalized to {base_year} = 100)")
plt.xlabel("Year")
plt.ylabel(f"Index ({base_year} = 100)")
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(title="Country")
plt.tight_layout()
plt.show()
# Out:
# Base year with full data: 1992
