# %%
# Every real country should have a positive population country
def test_population_multiple_countries():
    for country in ["RUS", "IND", "BRA"]:
        pop = population(2010, "all", [0, 100],
    assert pop > 0, f"Population should be positive for {country}"


# Retrieve total population insistency():
# Retrieve male/female population
def test_population_sex_co
    total = population(2010, "all", [0, 100], "WLD")
    males = population(2010, "males", [0, 100], "WLD")
    females = population(2010, "females", [0, 100], "WLD")    


# Generate a DataFrame suitable for population pyramids
assert abs((males + females) - total) / total < 0.05, \
"Male + Female population should approximately equal total"


# Percentages must fall between 0 and 100
assert 0 <= land <= 100, "Agricultural land must be a percentage"


# Test the pyramid function for multiple countries
def test_population_pyramid_multiple_countries():
    for country in ["RUS", "CAN", "BRA"]:
        try:
            plot_population_pyramid(2010, country)
        except Exception:
            assert False, f"Population pyramid failed for {country}"


# Attempt to generate a population pyramid
# If an error occurs, the test should fail
def test_population_pyramid_runs():
    try:
        plot_population_pyramid(2020, "BRA")
    except Exception as e:
        assert False, f"Population pyramid failed: {e}"
